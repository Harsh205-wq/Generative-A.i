# %%
### joining paths
import os
dir_name='folder'
file_name='file.txt'
fullpath=os.path.join(dir_name,file_name)
print(fullpath)
# Out:
# folder\file.txt

# %%
### listing files and dict
import os
items=os.listdir('.')
print(items)
# Out:
# ['destination.txt', 'example.bin', 'example.txt', 'fileoperation.ipynb', 'package']

# %%
### create a new dicratory
import os
new_dir='package'
os.mkdir(new_dir)

# %%
### read from source file and write to destination file

with open('example.txt','r') as source_file:
    content=source_file.read()
    
with open('destination.txt','w')as destination_file:
    destination_file.write(content)

# %%
with open('example.txt','r') as file:
    content=file.read()
    print(content)
# Out:
# hello this is harsh
# i am learning generative ai
# this is imp

# %%
with open('example.txt','r') as file:
    for line in file:
        print(line.strip())
# Out:
# hello this is harsh
# i am learning generative ai
# this is imp

# %%
with open('example.txt','w') as file:
    file.write('hello world!\n')
    file.write('this is new line..')

# %%
with open('example.txt','a') as file:
    file.write('hello world 2!\n')
    file.write('this is  2nd new line..')

# %%
### Binary files
