# %%
# !pip install nltk

# %%
corpus="Gen AI is transforming! the w!orld."

# %%
from nltk import word_tokenize

word_tokenize(corpus)
# Out:
# ['Gen', 'AI', 'is', 'transforming', '!', 'the', 'w', '!', 'orld', '.']

# %%
corpus2="Hello Harsh. You are learning NLP. Keep going!"
from nltk import sent_tokenize
sent_tokenize(corpus2)
# Out:
# ['Hello Harsh.', 'You are learning NLP.', 'Keep going!']

# %%
corpus3="AI is the future and AI is powerful"
from nltk import unique_list
