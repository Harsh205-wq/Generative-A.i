# %%
### Method overiding
class Animal:
    def speak(self):
        return "Sound of the animal"

class Dog(Animal):
    def speak(self):
        return "woof"
class Cat(Animal):
    def speak(self):
        return "Meow"
    
Dog=Dog()
cat=Cat()

print(Dog.speak())
print(cat.speak())
# Out:
# woof
# Meow

# %%
class Shape:
    def area(self):
        return "The area of the figure"
    
### Derived class 1
class Square(Shape):
    def __init__(self,width,height):
        self.width=width
        self.heigth=height
    
    def area(self):
        return self.width*self.heigth
### derived class 2
class Circle(Shape):
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        return 3.14*self.radius*self.radius
    
def print_area(shape):
    print(f"the area is {shape.area()}")

square=Square(4,5)
circle=Circle(3)

print_area(square)
print_area(circle)
# Out:
# the area is 20
# the area is 28.259999999999998

# %%
### Polymorphism with abstract class

### Abstract class Python me ek aisi class hoti hai jiska object create nahi kar sakte aur jisme abstract methods hote hain jo child classes ko implement karne padte hain.
from abc import ABC,abstractmethod
class Vechile(ABC):
    @abstractmethod
    def start_engine(self):
        pass
 ### derived class 1
class car(Vechile):
    def start_engine(self):
       return "Car engine started"
class MotorCycle(Vechile):
    def start_engine(self):
        return "Motocycle engine started"

### creates objects
