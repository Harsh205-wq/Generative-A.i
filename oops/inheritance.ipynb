# %%
## Inheritance
class Car:
    def __init__(self,windows,doors,enginetype):
        self.windows=windows
        self.doors=doors
        self.enginetype=enginetype
    
    def drive(self):
        print(f"drive the {self.enginetype} car fast")

# %%
car1=Car(4,5,"petrol")
car1.drive()
# Out:
# drive the petrol car fast

# %%
class Tesla(Car):
    def __init__(self, windows, doors, enginetype,isSelfDriving):
        super().__init__(windows, doors, enginetype)
        self.isSelfdriving=isSelfDriving
    def selfdriving(self):
        print("Tesla supports self driving")

car2=Tesla(41,53,"diesel",True)
car2.selfdriving()
car2.drive()
# Out:
# Tesla supports self driving
# drive the diesel car fast

# %%
### Multiple Inheritance
### Base class 1
class Car:
    def __init__(self,windows,doors,enginetype):
        self.windows=windows
        self.doors=doors
        self.enginetype=enginetype

### Base Class 2
class byce:
    def __init__(self,tyres):
        self.tyres=tyres

## Derived class   
class bullet(Car,byce):
    def __init__(self, windows, doors, enginetype, tyres):
        Car.__init__(self, windows, doors, enginetype)
        byce.__init__(self, tyres)
            
    def drive(self):
        return f"{self.windows} is windows"
