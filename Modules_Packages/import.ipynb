# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi
print(sqrt(16))
print(sqrt(25))
print(pi)
# Out:
# 4.0
# 5.0
# 3.141592653589793

# %%
import subprocess
import sys
subprocess.run([sys.executable, "-m", "pip", "install", "numpy"])
# Out:
# CompletedProcess(args=['c:\\Users\\Lenovo\\Documents\\Generative-A.I\\Python\\Basics\\venv\\python.exe', '-m', 'pip', 'install', 'numpy'], returncode=0)

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import *
sqrt(19)
# Out:
# 4.358898943540674

# %%
from package.maths import addition
addition(2,3)

from package import maths
maths.addition(5,6)
# Out:
# 11

# %%
from package.subpackage.divide import divide
divide(10,5)
# Out:
# 2.0

# %%
import random
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 1
# banana

# %%
### file and directory access
import os
print(os.getcwdb())
# Out:
# b'c:\\Users\\Lenovo\\Documents\\Generative-A.I\\Modules_Packages'

# %%
os.mkdir('test_dir')

# %%
### Data Serialization
import json
data={
    'name':'krish',
    'age':'35'
}

json_str=json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "krish", "age": "35"}
# <class 'str'>
# {'name': 'krish', 'age': '35'}
# <class 'dict'>

# %%
### csv
import csv

with open('example.csv',mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['krish',32])

with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['krish', '32']
