# %% [markdown]
# list are mutable, means value of list can altered

# %% [markdown]
# list contains any type of data type

# %%
### Accessing list items
fruits=["apple","banana","orange"]

# %%
fruits
fruits[0]
# Out:
# 'apple'
